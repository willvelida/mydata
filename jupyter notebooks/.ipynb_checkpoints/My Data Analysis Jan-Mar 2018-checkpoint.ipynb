# %% [markdown]
# # MyData Q1 Analysis (January - March 2018)

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import tensorflow as tf
import sklearn
import matplotlib.pyplot as plt

# %%
# Show the matplotlib inline
# %matplotlib inline

# %% [markdown]
# ## Importing the data files

# %% [markdown]
# ### Food Log

# %%
# Import the food log file
foodlog_df = pd.read_csv("https://mydataproject.blob.core.windows.net/csvfiles/FoodLog.csv", sep=",")
# print the head of the file
foodlog_df.head()
# Out:
#          Date  Calories In  Fat (g)  Fiber (g)  Carbs (g)  Sodium (mg)  \
# 0  01-01-2018         1221       18         12        100          614
# 1  02-01-2018         1156       48         10        128          847
# 2  03-01-2018         1861       33         16        252         1604
# 3  04-01-2018         1831       33         11        222         3423
# 4  05-01-2018         1227       35         10        140         1348
#
#    Protein (g)  Water (ml) WaterTargetAchieved UnderEaten  Unnamed: 10
# 0          150        2250                 Yes        Yes          NaN
# 1           48        2250                 Yes        Yes          NaN
# 2           82        1000                  No         No          NaN
# 3           61        1250                  No         No          NaN
# 4           71        3000                 Yes        Yes          NaN

# %%
# Drop unnamed column
foodlog_df2 = foodlog_df.drop(['Unnamed: 10'], axis=1)
# print out head
foodlog_df2.head()
# Out:
#          Date  Calories In  Fat (g)  Fiber (g)  Carbs (g)  Sodium (mg)  \
# 0  01-01-2018         1221       18         12        100          614
# 1  02-01-2018         1156       48         10        128          847
# 2  03-01-2018         1861       33         16        252         1604
# 3  04-01-2018         1831       33         11        222         3423
# 4  05-01-2018         1227       35         10        140         1348
#
#    Protein (g)  Water (ml) WaterTargetAchieved UnderEaten
# 0          150        2250                 Yes        Yes
# 1           48        2250                 Yes        Yes
# 2           82        1000                  No         No
# 3           61        1250                  No         No
# 4           71        3000                 Yes        Yes

# %%
def reset_index_on_int(file):
    file.index = np.arange(1, len(file) + 1)

# %%
# Set the index of the foodlog to 1
# foodlog_df2.index = np.arange(1, len(foodlog_df2) + 1)
reset_index_on_int(foodlog_df2)
# Print the head of the file
foodlog_df2.head()
# Out:
#          Date  Calories In  Fat (g)  Fiber (g)  Carbs (g)  Sodium (mg)  \
# 1  01-01-2018         1221       18         12        100          614
# 2  02-01-2018         1156       48         10        128          847
# 3  03-01-2018         1861       33         16        252         1604
# 4  04-01-2018         1831       33         11        222         3423
# 5  05-01-2018         1227       35         10        140         1348
#
#    Protein (g)  Water (ml) WaterTargetAchieved UnderEaten
# 1          150        2250                 Yes        Yes
# 2           48        2250                 Yes        Yes
# 3           82        1000                  No         No
# 4           61        1250                  No         No
# 5           71        3000                 Yes        Yes

# %%
# Print out information about our foodlog file
foodlog_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 1 to 118
# Data columns (total 10 columns):
# Date                   118 non-null object
# Calories In            118 non-null int64
# Fat (g)                118 non-null int64
# Fiber (g)              118 non-null int64
# Carbs (g)              118 non-null int64
# Sodium (mg)            118 non-null int64
# Protein (g)            118 non-null int64
# Water (ml)             118 non-null int64
# WaterTargetAchieved    118 non-null object
# UnderEaten             118 non-null object
# dtypes: int64(7), object(3)
# memory usage: 10.1+ KB

# %%
# Convert columns to necessary data formats
foodlog_df2['Date'] = pd.to_datetime(foodlog_df2['Date'],format='%d/%m/%Y', errors='ignore')
foodlog_df2['WaterTargetAchieved'] = foodlog_df2.WaterTargetAchieved.astype('category')
foodlog_df2['UnderEaten'] = foodlog_df2.UnderEaten.astype('category')
# Print out information to see if conversion was successful
foodlog_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 1 to 118
# Data columns (total 10 columns):
# Date                   118 non-null datetime64[ns]
# Calories In            118 non-null int64
# Fat (g)                118 non-null int64
# Fiber (g)              118 non-null int64
# Carbs (g)              118 non-null int64
# Sodium (mg)            118 non-null int64
# Protein (g)            118 non-null int64
# Water (ml)             118 non-null int64
# WaterTargetAchieved    118 non-null category
# UnderEaten             118 non-null category
# dtypes: category(2), datetime64[ns](1), int64(7)
# memory usage: 8.7 KB

# %%
# Filter out dataset with date range GITHUB ISSUE #1 NEED TO FIX DATETIME CONVERSION.
mask = (foodlog_df2['Date'] > '2017-12-31') & (foodlog_df2['Date'] < '2018-04-01')
# Apply mask to dataset and create new dataframe from it
foodlog_df3 = foodlog_df2.loc[mask]
# reset index of foodlog_df3
reset_index_on_int(foodlog_df3)
# show head of foodlog_df3
foodlog_df3.head()
# Out:
#         Date  Calories In  Fat (g)  Fiber (g)  Carbs (g)  Sodium (mg)  \
# 1 2018-01-01         1221       18         12        100          614
# 2 2018-02-01         1156       48         10        128          847
# 3 2018-03-01         1861       33         16        252         1604
# 4 2018-01-13         1516       33         28        171         1163
# 5 2018-01-14         1545       76         14         76         2680
#
#    Protein (g)  Water (ml) WaterTargetAchieved UnderEaten
# 1          150        2250                 Yes        Yes
# 2           48        2250                 Yes        Yes
# 3           82        1000                  No         No
# 4          129        2250                 Yes        Yes
# 5          135        2350                 Yes        Yes

# %%
foodlog_df3.head()
# Out:
#         Date  Calories In  Fat (g)  Fiber (g)  Carbs (g)  Sodium (mg)  \
# 1 2018-01-01         1221       18         12        100          614
# 2 2018-02-01         1156       48         10        128          847
# 3 2018-03-01         1861       33         16        252         1604
# 4 2018-01-13         1516       33         28        171         1163
# 5 2018-01-14         1545       76         14         76         2680
#
#    Protein (g)  Water (ml) WaterTargetAchieved UnderEaten
# 1          150        2250                 Yes        Yes
# 2           48        2250                 Yes        Yes
# 3           82        1000                  No         No
# 4          129        2250                 Yes        Yes
# 5          135        2350                 Yes        Yes

# %%
# show tail of foodlog_df3
foodlog_df3.tail()
# Out:
#          Date  Calories In  Fat (g)  Fiber (g)  Carbs (g)  Sodium (mg)  \
# 61 2018-03-30         1246       35          4        119         1981
# 62 2018-03-31         1488       31         24        154         1709
# 63 2018-01-04         2013       59         18        164         2518
# 64 2018-02-04         2581       65         19        283         2993
# 65 2018-03-04         1866       58         15        117         3456
#
#     Protein (g)  Water (ml) WaterTargetAchieved UnderEaten
# 61           93        3500                 Yes        Yes
# 62          135        3250                 Yes        Yes
# 63          187        3000                 Yes         No
# 64          162        3250                 Yes         No
# 65          204        3750                 Yes         No

# %%
# Drop last 3 rows of foodlog_df3 and apply to foodlog_df4
foodlog_df4 = foodlog_df3[:-3]
# Print tail of foodlog_df4 to confirm
foodlog_df4.tail()
# Out:
#          Date  Calories In  Fat (g)  Fiber (g)  Carbs (g)  Sodium (mg)  \
# 58 2018-03-27         1565       59          9        110         1978
# 59 2018-03-28         1979       63         26        176         2301
# 60 2018-03-29         1410       34         20        138         2574
# 61 2018-03-30         1246       35          4        119         1981
# 62 2018-03-31         1488       31         24        154         1709
#
#     Protein (g)  Water (ml) WaterTargetAchieved UnderEaten
# 58          141        3500                 Yes        Yes
# 59          174        3725                 Yes         No
# 60          133        3000                 Yes        Yes
# 61           93        3500                 Yes        Yes
# 62          135        3250                 Yes        Yes

# %% [markdown]
# ### Gym Workouts

# %%
# Import the gym workouts file
gymworkouts_df = pd.read_csv("https://mydataproject.blob.core.windows.net/csvfiles/GymWorkouts.csv", sep=",")
# print the head of the file
gymworkouts_df.head()
# Out:
#    ExerciseId  DateId Exercise Date Exercise Month  Exercise Year  \
# 0           1       1     6/11/2017       November           2017
# 1           2       1     6/11/2017       November           2017
# 2           3       1     6/11/2017       November           2017
# 3           4       1     6/11/2017       November           2017
# 4           5       2     8/11/2017       November           2017
#
#   Exercise Day     Exercise Name  Weight  Sets  Reps TrainingArea
# 0       Monday       Bench Press    90.0     5     5        Chest
# 1       Monday    Overhead Press    45.0     5     5        Chest
# 2       Monday       Barbell Row    80.0     5     5         Back
# 3       Monday  Assisted Pull up    23.0     5     5         Back
# 4    Wednesday     Barbell Squat    80.0     4     5         Legs

# %%
# Set the index of the gymworkouts to Exercise ID
gymworkouts_df.set_index('ExerciseId', inplace=True)
# Print the head of the file
gymworkouts_df.head()
# Out:
#             DateId Exercise Date Exercise Month  Exercise Year Exercise Day  \
# ExerciseId
# 1                1     6/11/2017       November           2017       Monday
# 2                1     6/11/2017       November           2017       Monday
# 3                1     6/11/2017       November           2017       Monday
# 4                1     6/11/2017       November           2017       Monday
# 5                2     8/11/2017       November           2017    Wednesday
#
#                Exercise Name  Weight  Sets  Reps TrainingArea
# ExerciseId
# 1                Bench Press    90.0     5     5        Chest
# 2             Overhead Press    45.0     5     5        Chest
# 3                Barbell Row    80.0     5     5         Back
# 4           Assisted Pull up    23.0     5     5         Back
# 5              Barbell Squat    80.0     4     5         Legs

# %%
# Check out datatypes for gymworkouts
gymworkouts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817 entries, 1 to 817
# Data columns (total 10 columns):
# DateId            817 non-null int64
# Exercise Date     817 non-null object
# Exercise Month    817 non-null object
# Exercise Year     817 non-null int64
# Exercise Day      817 non-null object
# Exercise Name     817 non-null object
# Weight            817 non-null float64
# Sets              817 non-null int64
# Reps              817 non-null int64
# TrainingArea      817 non-null object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 70.2+ KB

# %%
# Convert columns to necessary datatypes
gymworkouts_df['Exercise Date'] = pd.to_datetime(gymworkouts_df['Exercise Date'],format='%d/%m/%Y', errors='ignore')
# print out columns to ensure that data was converted
gymworkouts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817 entries, 1 to 817
# Data columns (total 10 columns):
# DateId            817 non-null int64
# Exercise Date     817 non-null datetime64[ns]
# Exercise Month    817 non-null object
# Exercise Year     817 non-null int64
# Exercise Day      817 non-null object
# Exercise Name     817 non-null object
# Weight            817 non-null float64
# Sets              817 non-null int64
# Reps              817 non-null int64
# TrainingArea      817 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 70.2+ KB

# %%
# print out head to ensure that conversion worked
gymworkouts_df.head()
# Out:
#             DateId Exercise Date Exercise Month  Exercise Year Exercise Day  \
# ExerciseId
# 1                1    2017-11-06       November           2017       Monday
# 2                1    2017-11-06       November           2017       Monday
# 3                1    2017-11-06       November           2017       Monday
# 4                1    2017-11-06       November           2017       Monday
# 5                2    2017-11-08       November           2017    Wednesday
#
#                Exercise Name  Weight  Sets  Reps TrainingArea
# ExerciseId
# 1                Bench Press    90.0     5     5        Chest
# 2             Overhead Press    45.0     5     5        Chest
# 3                Barbell Row    80.0     5     5         Back
# 4           Assisted Pull up    23.0     5     5         Back
# 5              Barbell Squat    80.0     4     5         Legs

# %%
# Filter out dataset with date range
mask = (gymworkouts_df['Exercise Date'] > '2017-12-31') & (gymworkouts_df['Exercise Date'] < '2018-04-01')
# Apply mask to dataset and create new dataframe from it
gymworkouts_df2 = gymworkouts_df.loc[mask]
# reset index of gymworkouts_df2
reset_index_on_int(gymworkouts_df2)
# show head of gymworkouts_df2
gymworkouts_df2.head()
# Out:
#    DateId Exercise Date Exercise Month  Exercise Year Exercise Day  \
# 1      37    2018-01-06        January           2018     Saturday
# 2      37    2018-01-06        January           2018     Saturday
# 3      37    2018-01-06        January           2018     Saturday
# 4      37    2018-01-06        January           2018     Saturday
# 5      37    2018-01-06        January           2018     Saturday
#
#     Exercise Name  Weight  Sets  Reps TrainingArea
# 1     Bench Press    95.0     5     5        Chest
# 2     Barbell Row    85.0     5     5         Back
# 3  Shoulder Press    26.0     4     8    Shoulders
# 4  Shoulder Shrug    26.0     4     8    Shoulders
# 5       Rear Delt    86.0     4     8         Back

# %%
# show tail of gymworkouts_df2
gymworkouts_df2.tail()
# Out:
#      DateId Exercise Date Exercise Month  Exercise Year Exercise Day  \
# 396      83    2018-03-30          March           2018       Friday
# 397      83    2018-03-30          March           2018       Friday
# 398      83    2018-03-30          March           2018       Friday
# 399      83    2018-03-30          March           2018       Friday
# 400      83    2018-03-30          March           2018       Friday
#
#           Exercise Name  Weight  Sets  Reps TrainingArea
# 396           Heel-taps     0.0     3    12         Core
# 397  Raised leg circles     0.0     3    10         Core
# 398            Scissors     0.0     3    12         Core
# 399       Knee-Pull ins     0.0     3    10         Core
# 400       Flitter Kicks     0.0     3    20         Core

# %% [markdown]
# ### Total Exercise

# %%
# Import the total exercise file
totalexercise_df = pd.read_csv("https://mydataproject.blob.core.windows.net/csvfiles/TotalExercise.csv", sep=",")
# print the head of the file
totalexercise_df.head()
# Out:
#         Date  Calories Burned  Steps  Distance  Floors Minutes Sedentary  \
# 0  1/09/2017             3721  13030      9.91       5               498
# 1  2/09/2017             3015   8147      6.35       3               732
# 2  3/09/2017             3837  13857     10.79       8               480
# 3  4/09/2017             4274  12846      9.79       8               593
# 4  5/09/2017             3519  11041      8.62       7              1044
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                     460                     13                   10
# 1                     223                     32                    2
# 2                     414                     26                   25
# 3                     334                     18                   87
# 4                     380                     10                    6
#
#    Activity Calories Step Target Achieved Calorie Target Achieved  \
# 0               2266                  Yes                     Yes
# 1               1245                  Yes                      No
# 2               2379                  Yes                     Yes
# 3               2757                  Yes                     Yes
# 4               1947                  Yes                     Yes
#
#   Activity Target Achieved Rest Day Distance Achieved
# 0                       No      Yes               Yes
# 1                       No       No               Yes
# 2                       No       No               Yes
# 3                      Yes       No               Yes
# 4                       No      Yes               Yes

# %%
# Set the index of the totalexercise to 1
reset_index_on_int(totalexercise_df)
# Print the head of the file
totalexercise_df.head()
# Out:
#         Date  Calories Burned  Steps  Distance  Floors Minutes Sedentary  \
# 1  1/09/2017             3721  13030      9.91       5               498
# 2  2/09/2017             3015   8147      6.35       3               732
# 3  3/09/2017             3837  13857     10.79       8               480
# 4  4/09/2017             4274  12846      9.79       8               593
# 5  5/09/2017             3519  11041      8.62       7              1044
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 1                     460                     13                   10
# 2                     223                     32                    2
# 3                     414                     26                   25
# 4                     334                     18                   87
# 5                     380                     10                    6
#
#    Activity Calories Step Target Achieved Calorie Target Achieved  \
# 1               2266                  Yes                     Yes
# 2               1245                  Yes                      No
# 3               2379                  Yes                     Yes
# 4               2757                  Yes                     Yes
# 5               1947                  Yes                     Yes
#
#   Activity Target Achieved Rest Day Distance Achieved
# 1                       No      Yes               Yes
# 2                       No       No               Yes
# 3                       No       No               Yes
# 4                      Yes       No               Yes
# 5                       No      Yes               Yes

# %%
totalexercise_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242 entries, 1 to 242
# Data columns (total 15 columns):
# Date                        242 non-null object
# Calories Burned             242 non-null int64
# Steps                       242 non-null int64
# Distance                    242 non-null float64
# Floors                      242 non-null int64
# Minutes Sedentary           242 non-null object
# Minutes Lightly Active      242 non-null int64
# Minutes Fairly Active       242 non-null int64
# Minutes Very Active         242 non-null int64
# Activity Calories           242 non-null int64
# Step Target Achieved        242 non-null object
# Calorie Target Achieved     242 non-null object
# Activity Target Achieved    242 non-null object
# Rest Day                    242 non-null object
# Distance Achieved           242 non-null object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 30.2+ KB

# %%
# Convert columns to necessary datatypes
totalexercise_df['Date'] = pd.to_datetime(totalexercise_df['Date'],format='%d/%m/%Y', errors='ignore')
# print out columns to ensure that data was converted
totalexercise_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242 entries, 1 to 242
# Data columns (total 15 columns):
# Date                        242 non-null datetime64[ns]
# Calories Burned             242 non-null int64
# Steps                       242 non-null int64
# Distance                    242 non-null float64
# Floors                      242 non-null int64
# Minutes Sedentary           242 non-null object
# Minutes Lightly Active      242 non-null int64
# Minutes Fairly Active       242 non-null int64
# Minutes Very Active         242 non-null int64
# Activity Calories           242 non-null int64
# Step Target Achieved        242 non-null object
# Calorie Target Achieved     242 non-null object
# Activity Target Achieved    242 non-null object
# Rest Day                    242 non-null object
# Distance Achieved           242 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(7), object(6)
# memory usage: 30.2+ KB

# %%
totalexercise_df.head()
# Out:
#         Date  Calories Burned  Steps  Distance  Floors Minutes Sedentary  \
# 1 2017-09-01             3721  13030      9.91       5               498
# 2 2017-09-02             3015   8147      6.35       3               732
# 3 2017-09-03             3837  13857     10.79       8               480
# 4 2017-09-04             4274  12846      9.79       8               593
# 5 2017-09-05             3519  11041      8.62       7              1044
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 1                     460                     13                   10
# 2                     223                     32                    2
# 3                     414                     26                   25
# 4                     334                     18                   87
# 5                     380                     10                    6
#
#    Activity Calories Step Target Achieved Calorie Target Achieved  \
# 1               2266                  Yes                     Yes
# 2               1245                  Yes                      No
# 3               2379                  Yes                     Yes
# 4               2757                  Yes                     Yes
# 5               1947                  Yes                     Yes
#
#   Activity Target Achieved Rest Day Distance Achieved
# 1                       No      Yes               Yes
# 2                       No       No               Yes
# 3                       No       No               Yes
# 4                      Yes       No               Yes
# 5                       No      Yes               Yes

# %%
# Filter out dataset with date range
mask = (totalexercise_df['Date'] > '2017-12-31') & (totalexercise_df['Date'] < '2018-04-01')
# Apply mask to dataset and create new dataframe from it
totalexercise_df2 = totalexercise_df.loc[mask]
# reset index of totalexercise_df2
reset_index_on_int(totalexercise_df2)
# show head of total exercise_df2
totalexercise_df2.head()
# Out:
#         Date  Calories Burned  Steps  Distance  Floors Minutes Sedentary  \
# 1 2018-01-01             3006   6574      5.11       0               699
# 2 2018-01-02             3262   8239      6.43      16               812
# 3 2018-01-03             3372   6634      5.17      23               658
# 4 2018-01-04             3765  15038     11.73       4               582
# 5 2018-01-05             3195   7481      5.84       9               699
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 1                     295                      0                    0
# 2                     312                      0                    0
# 3                     268                      0                    0
# 4                     228                     29                   67
# 5                     229                     19                    0
#
#    Activity Calories Step Target Achieved Calorie Target Achieved  \
# 1               1265                   No                      No
# 2               1485                  Yes                      No
# 3               1403                   No                      No
# 4               1943                  Yes                     Yes
# 5               1212                   No                      No
#
#   Activity Target Achieved Rest Day Distance Achieved
# 1                       No      Yes               Yes
# 2                       No      Yes               Yes
# 3                       No      Yes               Yes
# 4                      Yes       No               Yes
# 5                       No      Yes               Yes

# %%
# show tail of total_exercise_df2
totalexercise_df2.tail()
# Out:
#          Date  Calories Burned  Steps  Distance  Floors Minutes Sedentary  \
# 86 2018-03-27             3694  13497     10.53      23               672
# 87 2018-03-28             3935  12884      9.68      10               638
# 88 2018-03-29             3248  10560      8.24      10               710
# 89 2018-03-30             3269   9181      6.95      18               737
# 90 2018-03-31             2934   7461      6.00      11               691
#
#     Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 86                     298                     37                   33
# 87                     336                     12                   68
# 88                     344                      4                    5
# 89                     318                      7                    2
# 90                     302                      0                    0
#
#     Activity Calories Step Target Achieved Calorie Target Achieved  \
# 86               1982                  Yes                     Yes
# 87               2404                  Yes                     Yes
# 88               1620                  Yes                      No
# 89               1604                  Yes                      No
# 90               1274                   No                      No
#
#    Activity Target Achieved Rest Day Distance Achieved
# 86                      Yes       No               Yes
# 87                      Yes       No               Yes
# 88                       No      Yes               Yes
# 89                       No      Yes               Yes
# 90                       No      Yes               Yes

# %% [markdown]
# #### Data Exploration

# %%
# Create a box plots for calories burned against various categorical data
totalexercise_df2.boxplot(column='Calories Burned', by='Step Target Achieved', rot=90)
totalexercise_df2.boxplot(column='Calories Burned', by='Calorie Target Achieved', rot=90)
totalexercise_df2.boxplot(column='Calories Burned', by='Activity Target Achieved', rot=90)
totalexercise_df2.boxplot(column='Calories Burned', by='Rest Day', rot=90)
totalexercise_df2.boxplot(column='Calories Burned', by='Distance Achieved', rot=90)

# show plots
plt.show()
# Out:
# C:\Users\Will\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# ### Total Sleep

# %%
# Import the total sleep file
totalsleep_df = pd.read_csv("https://mydataproject.blob.core.windows.net/csvfiles/TotalSleep.csv", sep=",")
# print the head of the file
totalsleep_df.head()
# Out:
#    Start Time   End Time  Minutes Asleep  Minutes Awake  Number of Awakenings  \
# 0  31/08/2017  1/09/2017             320             45                    30
# 1   1/09/2017  2/09/2017             402             49                    35
# 2   2/09/2017  3/09/2017             456             39                    34
# 3   3/09/2017  4/09/2017             362             46                    30
# 4   5/09/2017  6/09/2017             370             47                    29
#
#    Time in Bed  Minutes REM Sleep  Minutes Light Sleep  Minutes Deep Sleep  \
# 0          365               47.0                200.0                73.0
# 1          451               79.0                237.0                86.0
# 2          495              118.0                228.0               110.0
# 3          408               63.0                188.0               111.0
# 4          417               15.0                271.0                84.0
#
#   Sleep Target Achieved  % Asleep  % Awake % Light sleep % REM Sleep  \
# 0                    No     87.67    12.33         54.79       12.88
# 1                    No     89.14    10.86         52.55       17.52
# 2                   Yes     92.12     7.88         46.06       23.84
# 3                    No     88.73    11.27         46.08       15.44
# 4                    No     88.73    11.27         64.99        3.60
#
#   % Deep Sleep % Unclassified
# 0        20.00          12.33
# 1        19.07          10.86
# 2        22.22           7.88
# 3        27.21          11.27
# 4        20.14          11.27

# %%
# Set the index of the totalsleep to 1
reset_index_on_int(totalsleep_df)
# Print the head of the file
totalsleep_df.head()
# Out:
#    Start Time   End Time  Minutes Asleep  Minutes Awake  Number of Awakenings  \
# 1  31/08/2017  1/09/2017             320             45                    30
# 2   1/09/2017  2/09/2017             402             49                    35
# 3   2/09/2017  3/09/2017             456             39                    34
# 4   3/09/2017  4/09/2017             362             46                    30
# 5   5/09/2017  6/09/2017             370             47                    29
#
#    Time in Bed  Minutes REM Sleep  Minutes Light Sleep  Minutes Deep Sleep  \
# 1          365               47.0                200.0                73.0
# 2          451               79.0                237.0                86.0
# 3          495              118.0                228.0               110.0
# 4          408               63.0                188.0               111.0
# 5          417               15.0                271.0                84.0
#
#   Sleep Target Achieved  % Asleep  % Awake % Light sleep % REM Sleep  \
# 1                    No     87.67    12.33         54.79       12.88
# 2                    No     89.14    10.86         52.55       17.52
# 3                   Yes     92.12     7.88         46.06       23.84
# 4                    No     88.73    11.27         46.08       15.44
# 5                    No     88.73    11.27         64.99        3.60
#
#   % Deep Sleep % Unclassified
# 1        20.00          12.33
# 2        19.07          10.86
# 3        22.22           7.88
# 4        27.21          11.27
# 5        20.14          11.27

# %%
totalsleep_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 210 entries, 1 to 210
# Data columns (total 16 columns):
# Start Time               210 non-null object
# End Time                 210 non-null object
# Minutes Asleep           210 non-null int64
# Minutes Awake            210 non-null int64
# Number of Awakenings     210 non-null int64
# Time in Bed              210 non-null int64
# Minutes REM Sleep        209 non-null float64
# Minutes Light Sleep      209 non-null float64
# Minutes Deep Sleep       209 non-null float64
# Sleep Target Achieved    210 non-null object
# % Asleep                 210 non-null float64
# % Awake                  210 non-null float64
# % Light sleep            210 non-null object
# % REM Sleep              210 non-null object
# % Deep Sleep             210 non-null object
# % Unclassified           210 non-null object
# dtypes: float64(5), int64(4), object(7)
# memory usage: 27.9+ KB

# %%
# Convert columns to necessary datatypes
totalsleep_df['Start Time'] = pd.to_datetime(totalsleep_df['Start Time'],format='%d/%m/%Y', errors='ignore')
totalsleep_df['End Time'] = pd.to_datetime(totalsleep_df['End Time'],format='%d/%m/%Y', errors='ignore')
# print out columns to ensure that data was converted
totalsleep_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 210 entries, 1 to 210
# Data columns (total 16 columns):
# Start Time               210 non-null datetime64[ns]
# End Time                 210 non-null datetime64[ns]
# Minutes Asleep           210 non-null int64
# Minutes Awake            210 non-null int64
# Number of Awakenings     210 non-null int64
# Time in Bed              210 non-null int64
# Minutes REM Sleep        209 non-null float64
# Minutes Light Sleep      209 non-null float64
# Minutes Deep Sleep       209 non-null float64
# Sleep Target Achieved    210 non-null object
# % Asleep                 210 non-null float64
# % Awake                  210 non-null float64
# % Light sleep            210 non-null object
# % REM Sleep              210 non-null object
# % Deep Sleep             210 non-null object
# % Unclassified           210 non-null object
# dtypes: datetime64[ns](2), float64(5), int64(4), object(5)
# memory usage: 27.9+ KB

# %%
totalsleep_df.head()
# Out:
#   Start Time   End Time  Minutes Asleep  Minutes Awake  Number of Awakenings  \
# 1 2017-08-31 2017-01-09             320             45                    30
# 2 2017-01-09 2017-02-09             402             49                    35
# 3 2017-02-09 2017-03-09             456             39                    34
# 4 2017-03-09 2017-04-09             362             46                    30
# 5 2017-05-09 2017-06-09             370             47                    29
#
#    Time in Bed  Minutes REM Sleep  Minutes Light Sleep  Minutes Deep Sleep  \
# 1          365               47.0                200.0                73.0
# 2          451               79.0                237.0                86.0
# 3          495              118.0                228.0               110.0
# 4          408               63.0                188.0               111.0
# 5          417               15.0                271.0                84.0
#
#   Sleep Target Achieved  % Asleep  % Awake % Light sleep % REM Sleep  \
# 1                    No     87.67    12.33         54.79       12.88
# 2                    No     89.14    10.86         52.55       17.52
# 3                   Yes     92.12     7.88         46.06       23.84
# 4                    No     88.73    11.27         46.08       15.44
# 5                    No     88.73    11.27         64.99        3.60
#
#   % Deep Sleep % Unclassified
# 1        20.00          12.33
# 2        19.07          10.86
# 3        22.22           7.88
# 4        27.21          11.27
# 5        20.14          11.27

# %% [markdown]
# ### Weight Measurements

# %%
# Import the weight measurements file
weightmeasurements_df = pd.read_csv("https://mydataproject.blob.core.windows.net/csvfiles/WeightMeasurements.csv", sep=",")
# print the head of the file
weightmeasurements_df.head()
# Out:
#    WeightID        Date  Weight (Stone)  Weight (Kg)  Weight (lbs)  \
# 0         1  25/12/2017           16.80        105.0         231.0
# 1         2   1/01/2018           16.70        104.7         230.0
# 2         3   8/01/2018           16.20        102.5         225.9
# 3         4  15/01/2018           15.13        101.1         222.8
# 4         5  22/01/2018           15.11        100.2         220.9
#
#    Gain/Loss Amount (lbs)    BMI  BodyFat (%)
# 0                     0.0  29.71          NaN
# 1                    -1.0  29.62          NaN
# 2                    -4.1  29.00          NaN
# 3                    -3.1  28.60          NaN
# 4                    -1.9  28.35          NaN

# %%
# Set the index of the weight measurements to weightID column
weightmeasurements_df.set_index('WeightID', inplace=True)
# Print the head of the file
weightmeasurements_df.head()
# Out:
#                 Date  Weight (Stone)  Weight (Kg)  Weight (lbs)  \
# WeightID
# 1         25/12/2017           16.80        105.0         231.0
# 2          1/01/2018           16.70        104.7         230.0
# 3          8/01/2018           16.20        102.5         225.9
# 4         15/01/2018           15.13        101.1         222.8
# 5         22/01/2018           15.11        100.2         220.9
#
#           Gain/Loss Amount (lbs)    BMI  BodyFat (%)
# WeightID
# 1                            0.0  29.71          NaN
# 2                           -1.0  29.62          NaN
# 3                           -4.1  29.00          NaN
# 4                           -3.1  28.60          NaN
# 5                           -1.9  28.35          NaN

# %%
weightmeasurements_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 1 to 18
# Data columns (total 7 columns):
# Date                      18 non-null object
# Weight (Stone)            18 non-null float64
# Weight (Kg)               18 non-null float64
# Weight (lbs)              18 non-null float64
# Gain/Loss Amount (lbs)    18 non-null float64
# BMI                       18 non-null float64
# BodyFat (%)               10 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 1.1+ KB

# %%
# Convert columns to necessary datatypes
weightmeasurements_df['Date'] = pd.to_datetime(weightmeasurements_df['Date'], format='%d/%m/%Y', errors='ignore')
# print out columns to ensure that data was converted
weightmeasurements_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 1 to 18
# Data columns (total 7 columns):
# Date                      18 non-null datetime64[ns]
# Weight (Stone)            18 non-null float64
# Weight (Kg)               18 non-null float64
# Weight (lbs)              18 non-null float64
# Gain/Loss Amount (lbs)    18 non-null float64
# BMI                       18 non-null float64
# BodyFat (%)               10 non-null float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 1.1 KB

# %%
weightmeasurements_df
# Out:
#                Date  Weight (Stone)  Weight (Kg)  Weight (lbs)  \
# WeightID
# 1        2017-12-25           16.80        105.0         231.0
# 2        2018-01-01           16.70        104.7         230.0
# 3        2018-01-08           16.20        102.5         225.9
# 4        2018-01-15           15.13        101.1         222.8
# 5        2018-01-22           15.11        100.2         220.9
# 6        2018-01-28           15.11        100.2         220.9
# 7        2018-02-08           15.08         99.0         218.0
# 8        2018-02-17           15.06         97.9         215.8
# 9        2018-02-26           14.13         94.8         209.0
# 10       2018-03-04           15.04         95.4         210.3
# 11       2018-03-11           14.12         94.3         208.0
# 12       2018-03-18           14.10         93.4         205.9
# 13       2018-03-25           14.11         93.8         207.0
# 14       2018-04-01           14.10         93.4         205.9
# 15       2018-04-09           14.11         93.8         207.0
# 16       2018-04-15           14.11         93.8         207.0
# 17       2018-04-22           14.13         94.8         209.0
# 18       2018-04-30           14.13         94.8         209.0
#
#           Gain/Loss Amount (lbs)    BMI  BodyFat (%)
# WeightID
# 1                            0.0  29.71          NaN
# 2                           -1.0  29.62          NaN
# 3                           -4.1  29.00          NaN
# 4                           -3.1  28.60          NaN
# 5                           -1.9  28.35          NaN
# 6                            0.0  28.35          NaN
# 7                           -2.9  28.01          NaN
# 8                           -2.2  27.70          NaN
# 9                           -6.8  26.82         18.6
# 10                           1.3  26.99         20.8
# 11                          -2.3  26.68         20.8
# 12                          -2.1  26.43         20.8
# 13                           1.1  26.54         20.6
# 14                          -1.1  26.44         20.5
# 15                           1.1  26.54         20.6
# 16                           0.0  26.54         20.7
# 17                           2.0  26.82         20.6
# 18                           0.0  26.82         20.6

# %%
# Filter out dataset with date range
mask = (weightmeasurements_df['Date'] > '2017-12-31') & (weightmeasurements_df['Date'] < '2018-03-31')
# Apply mask to dataset and create new dataframe from it
weightmeasurements_df2 = weightmeasurements_df.loc[mask]
# reset index of totalexercise_df2
reset_index_on_int(weightmeasurements_df2)
# show head of total exercise_df2
weightmeasurements_df2
# Out:
#          Date  Weight (Stone)  Weight (Kg)  Weight (lbs)  \
# 1  2018-01-01           16.70        104.7         230.0
# 2  2018-01-08           16.20        102.5         225.9
# 3  2018-01-15           15.13        101.1         222.8
# 4  2018-01-22           15.11        100.2         220.9
# 5  2018-01-28           15.11        100.2         220.9
# 6  2018-02-08           15.08         99.0         218.0
# 7  2018-02-17           15.06         97.9         215.8
# 8  2018-02-26           14.13         94.8         209.0
# 9  2018-03-04           15.04         95.4         210.3
# 10 2018-03-11           14.12         94.3         208.0
# 11 2018-03-18           14.10         93.4         205.9
# 12 2018-03-25           14.11         93.8         207.0
#
#     Gain/Loss Amount (lbs)    BMI  BodyFat (%)
# 1                     -1.0  29.62          NaN
# 2                     -4.1  29.00          NaN
# 3                     -3.1  28.60          NaN
# 4                     -1.9  28.35          NaN
# 5                      0.0  28.35          NaN
# 6                     -2.9  28.01          NaN
# 7                     -2.2  27.70          NaN
# 8                     -6.8  26.82         18.6
# 9                      1.3  26.99         20.8
# 10                    -2.3  26.68         20.8
# 11                    -2.1  26.43         20.8
# 12                     1.1  26.54         20.6
